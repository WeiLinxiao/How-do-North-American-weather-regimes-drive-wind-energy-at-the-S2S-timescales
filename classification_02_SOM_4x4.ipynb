# %%
import pandas as pd
import xarray as xr
import numpy as np
from glob import glob
from yllib.function import mysom

# %%
year1   = 1981
year2   = 2020
season  = 'cold'
months  = [10,11,12,1,2,3]
# season  = 'warm'
# months  = [4,5,6,7,8,9]
mapsize = (4,4)
factor  = ('z')
bmu_filename = f"som/{season}_z_{mapsize[0]}x{mapsize[1]}.nc"
bmu_filename
# Out:
# 'som/cold_z_4x4.nc'

# %%
data = xr.open_dataset('data/hgt_daily_anomaly.nc')
# select months 
data = data.sel(time=data['time.month'].isin(months))
# select 500-hpa geopotential height for SOM
data = data['z500']
# convert to 1D
data = mysom.convert_to_1D(data)

# %%
import sompy
def calc_som(data, mapsize=[8,8]):
    dims = data.shape
    print(data)
    som = sompy.SOMFactory.build(data.data, mapsize, mask=None, mapshape='planar',
                                 lattice='rect', normalization="var",
                                 initialization='pca',
                                 neighborhood='gaussian',
                                 training='batch',
                                 name='sompy')  # this will use the default parameters, but i can change the initialization and neighborhood methods
    som.train(n_job=1, verbose='info', train_rough_len=100, train_finetune_len=50)
    topographic_error = som.calculate_topographic_error()
#    map_optimal_size = som.calculate_map_size(lattice='rect')
#    print(map_optimal_size)
    quantization_error = np.mean(som._bmu[1])
    print(topographic_error)
    print(quantization_error)

    bmu = som._bmu[0]
    bmu = xr.DataArray(bmu, dims=['time'], coords={'time': np.arange(dims[0])}, name='bmu')
    print(bmu)
#        v = sompy.mapview.View2DPacked(*mapsize, 'test',text_size=8)  
#        c1 = som.cluster(n_clusters=4)
#        v.show(som, what="cluster")
#        print(som.cluster_labels)
#        bmu = bmu.assign_attrs({"cluster":som.cluster_labels})
#        h = sompy.hitmap.HitMapView(*mapsize, 'hitmap', text_size=8, show_text=True)
#        h.show(som)

#        u = sompy.umatrix.UMatrixView(100, 100, 'umatrix', show_axis=True, text_size=8, show_text=True)

    #This is the Umat value
#        UMAT  = u.build_u_matrix(som, distance=1, row_normalized=False)

#        UMAT = u.show(som, distance=1, row_normalized=False, show_data=True, contour=True, blob=False)
    return bmu

# %%
bmu = calc_som(data, mapsize=mapsize)
# Out:
# <xarray.DataArray 'preSOM' (time: 7290, z: 11651)>
# array([[ 307.19569639,  430.7513085 ,  548.52521231, ...,   -3.33405712,
#          -11.32420314,  -18.08370517],
#        [ -16.50076608,   54.92982404,  142.58657422, ...,    2.32959031,
#           -5.90205393,  -10.93550531],
#        [ 176.45973612,  240.87277372,  285.4887377 , ...,  -32.81129443,
#          -44.14736339,  -52.68890047],
#        ...,
#        [-170.64117719,  -95.08775797,  -64.20567834, ...,   37.26571836,
#           30.8648394 ,   22.22764533],
#        [-271.98736096, -128.86410444,   15.60254168, ...,  125.90605032,
#          114.32568725,  110.08770486],
#        [-365.42012183, -290.67908799, -237.41636479, ...,  325.96106732,
#          304.92913245,  284.37740867]])
# Coordinates:
#   * time       (time) datetime64[ns] 1981-01-01 1981-01-02 ... 2020-12-31
#     dayofyear  (time) int64 ...
#     longitude  (z) float64 150.0 150.0 150.0 150.0 ... 340.0 340.0 340.0 340.0
#     latitude   (z) float64 70.0 69.0 68.0 67.0 66.0 ... 14.0 13.0 12.0 11.0 10.0
#   * z          (z) int64 0 1 2 3 4 5 6 ... 11645 11646 11647 11648 11649 11650
#  Training...
#  pca_linear_initialization took: 2.354000 seconds
#  Rough training...
#  radius_ini: 1.000000 , radius_final: 1.000000, trainlen: 100
#
#  epoch: 1 ---> elapsed time:  1.549000, quantization error: 525.954242
#
#  epoch: 2 ---> elapsed time:  1.477000, quantization error: 99.820316
#
#  epoch: 3 ---> elapsed time:  1.440000, quantization error: 97.646188
#
#  epoch: 4 ---> elapsed time:  1.713000, quantization error: 97.432798
#
#  epoch: 5 ---> elapsed time:  1.423000, quantization error: 97.270236
#
#  epoch: 6 ---> elapsed time:  1.350000, quantization error: 97.146465
#
#  epoch: 7 ---> elapsed time:  1.425000, quantization error: 97.046239
#
#  epoch: 8 ---> elapsed time:  1.307000, quantization error: 96.977776
#
#  epoch: 9 ---> elapsed time:  1.342000, quantization error: 96.932353
#
#  epoch: 10 ---> elapsed time:  1.502000, quantization error: 96.898078
#
#  epoch: 11 ---> elapsed time:  1.571000, quantization error: 96.873223
#
#  epoch: 12 ---> elapsed time:  1.639000, quantization error: 96.855880
#
#  epoch: 13 ---> elapsed time:  1.679000, quantization error: 96.843076
#
#  epoch: 14 ---> elapsed time:  1.672000, quantization error: 96.834277
#
#  epoch: 15 ---> elapsed time:  1.851000, quantization error: 96.829372
#
#  epoch: 16 ---> elapsed time:  2.486000, quantization error: 96.825351
#
#  epoch: 17 ---> elapsed time:  1.716000, quantization error: 96.821294
#
#  epoch: 18 ---> elapsed time:  1.811000, quantization error: 96.819293
#
#  epoch: 19 ---> elapsed time:  1.823000, quantization error: 96.818838
#
#  epoch: 20 ---> elapsed time:  1.719000, quantization error: 96.819292
#
#  epoch: 21 ---> elapsed time:  1.825000, quantization error: 96.817708
#
#  epoch: 22 ---> elapsed time:  1.716000, quantization error: 96.817310
#
#  epoch: 23 ---> elapsed time:  1.826000, quantization error: 96.816253
#
#  epoch: 24 ---> elapsed time:  1.727000, quantization error: 96.816129
#
#  epoch: 25 ---> elapsed time:  1.733000, quantization error: 96.815226
#
#  epoch: 26 ---> elapsed time:  1.724000, quantization error: 96.814932
#
#  epoch: 27 ---> elapsed time:  1.790000, quantization error: 96.813166
#
#  epoch: 28 ---> elapsed time:  1.823000, quantization error: 96.812074
#
#  epoch: 29 ---> elapsed time:  1.721000, quantization error: 96.812195
#
#  epoch: 30 ---> elapsed time:  1.720000, quantization error: 96.811942
#
#  epoch: 31 ---> elapsed time:  1.738000, quantization error: 96.811522
#
#  epoch: 32 ---> elapsed time:  1.707000, quantization error: 96.810460
#
#  epoch: 33 ---> elapsed time:  1.732000, quantization error: 96.808749
#
#  epoch: 34 ---> elapsed time:  1.857000, quantization error: 96.807149
#
#  epoch: 35 ---> elapsed time:  1.728000, quantization error: 96.805756
#
#  epoch: 36 ---> elapsed time:  1.724000, quantization error: 96.805410
#
#  epoch: 37 ---> elapsed time:  1.722000, quantization error: 96.804885
#
#  epoch: 38 ---> elapsed time:  1.717000, quantization error: 96.804345
#
#  epoch: 39 ---> elapsed time:  1.741000, quantization error: 96.803970
#
#  epoch: 40 ---> elapsed time:  1.778000, quantization error: 96.803094
#
#  epoch: 41 ---> elapsed time:  1.874000, quantization error: 96.802896
#
#
#  epoch: 86 ---> elapsed time:  1.712000, quantization error: 96.797921
#
#  epoch: 87 ---> elapsed time:  1.717000, quantization error: 96.797921
#
#  epoch: 88 ---> elapsed time:  1.828000, quantization error: 96.797921
#
#  epoch: 89 ---> elapsed time:  1.725000, quantization error: 96.797921
#
#  epoch: 90 ---> elapsed time:  1.724000, quantization error: 96.797921
#
#  epoch: 91 ---> elapsed time:  1.790000, quantization error: 96.797921
#
#  epoch: 92 ---> elapsed time:  1.711000, quantization error: 96.797921
#
#  epoch: 93 ---> elapsed time:  1.771000, quantization error: 96.797921
#
#  epoch: 94 ---> elapsed time:  1.694000, quantization error: 96.797921
#
#  epoch: 95 ---> elapsed time:  1.698000, quantization error: 96.797921
#
#  epoch: 96 ---> elapsed time:  1.701000, quantization error: 96.797921
#
#  epoch: 97 ---> elapsed time:  1.711000, quantization error: 96.797921
#
#  epoch: 98 ---> elapsed time:  1.695000, quantization error: 96.797921
#
#  epoch: 99 ---> elapsed time:  1.727000, quantization error: 96.797921
#
#  epoch: 100 ---> elapsed time:  1.691000, quantization error: 96.797921
#
#  Finetune training...
#  radius_ini: 1.000000 , radius_final: 1.000000, trainlen: 50
#
#  epoch: 1 ---> elapsed time:  1.701000, quantization error: 96.797921
#
#  epoch: 2 ---> elapsed time:  1.811000, quantization error: 96.797921
#
#  epoch: 3 ---> elapsed time:  1.704000, quantization error: 96.797921
#
#  epoch: 4 ---> elapsed time:  1.781000, quantization error: 96.797921
#
#  epoch: 5 ---> elapsed time:  1.720000, quantization error: 96.797921
#
#  epoch: 6 ---> elapsed time:  1.698000, quantization error: 96.797921
#
#  epoch: 7 ---> elapsed time:  1.713000, quantization error: 96.797921
#
#  epoch: 8 ---> elapsed time:  1.695000, quantization error: 96.797921
#
#  epoch: 9 ---> elapsed time:  1.801000, quantization error: 96.797921
#
#  epoch: 10 ---> elapsed time:  1.758000, quantization error: 96.797921
#
#  epoch: 11 ---> elapsed time:  1.612000, quantization error: 96.797921
#
#  epoch: 12 ---> elapsed time:  1.697000, quantization error: 96.797921
#
#  epoch: 13 ---> elapsed time:  1.711000, quantization error: 96.797921
#
#  epoch: 14 ---> elapsed time:  1.726000, quantization error: 96.797921
#
#  epoch: 15 ---> elapsed time:  1.707000, quantization error: 96.797921
#
#  epoch: 16 ---> elapsed time:  1.707000, quantization error: 96.797921
#
#  epoch: 17 ---> elapsed time:  1.700000, quantization error: 96.797921
#
#  epoch: 18 ---> elapsed time:  1.711000, quantization error: 96.797921
#
#  epoch: 19 ---> elapsed time:  1.707000, quantization error: 96.797921
#
#  epoch: 20 ---> elapsed time:  1.715000, quantization error: 96.797921
#
#  epoch: 21 ---> elapsed time:  1.712000, quantization error: 96.797921
#
#  epoch: 22 ---> elapsed time:  1.703000, quantization error: 96.797921
#
#  epoch: 23 ---> elapsed time:  1.755000, quantization error: 96.797921
#
#  epoch: 24 ---> elapsed time:  1.692000, quantization error: 96.797921
#
#  epoch: 25 ---> elapsed time:  1.786000, quantization error: 96.797921
#
#  epoch: 26 ---> elapsed time:  1.710000, quantization error: 96.797921
#
#  epoch: 27 ---> elapsed time:  1.697000, quantization error: 96.797921
#
#  epoch: 28 ---> elapsed time:  1.699000, quantization error: 96.797921
#
#  epoch: 29 ---> elapsed time:  1.715000, quantization error: 96.797921
#
#  epoch: 30 ---> elapsed time:  1.787000, quantization error: 96.797921
#
#  epoch: 31 ---> elapsed time:  1.711000, quantization error: 96.797921
#
#  epoch: 32 ---> elapsed time:  1.699000, quantization error: 96.797921
#
#  epoch: 33 ---> elapsed time:  1.710000, quantization error: 96.797921
#
#  epoch: 34 ---> elapsed time:  1.707000, quantization error: 96.797921
#
#  epoch: 35 ---> elapsed time:  1.654000, quantization error: 96.797921
#
#  epoch: 36 ---> elapsed time:  1.615000, quantization error: 96.797921
#
#  epoch: 37 ---> elapsed time:  1.811000, quantization error: 96.797921
#
#  epoch: 38 ---> elapsed time:  1.718000, quantization error: 96.797921
#
#  epoch: 39 ---> elapsed time:  1.679000, quantization error: 96.797921
#
#  epoch: 40 ---> elapsed time:  1.519000, quantization error: 96.797921
#
#  epoch: 41 ---> elapsed time:  1.490000, quantization error: 96.797921
#
#  epoch: 42 ---> elapsed time:  1.390000, quantization error: 96.797921
#
#  epoch: 43 ---> elapsed time:  1.383000, quantization error: 96.797921
#
#  epoch: 44 ---> elapsed time:  1.379000, quantization error: 96.797921
#
#  epoch: 45 ---> elapsed time:  1.369000, quantization error: 96.797921
#
#  epoch: 46 ---> elapsed time:  1.364000, quantization error: 96.797921
#
#  epoch: 47 ---> elapsed time:  1.372000, quantization error: 96.797921
#
#  epoch: 48 ---> elapsed time:  1.441000, quantization error: 96.797921
#
#  epoch: 49 ---> elapsed time:  1.367000, quantization error: 96.797921
#
#  epoch: 50 ---> elapsed time:  1.362000, quantization error: 96.797921
#
#  Final quantization error: 96.797921
#  train took: 256.994000 seconds
# 0.047736625514403296
# 96.79792072931389
# <xarray.DataArray 'bmu' (time: 7290)>
# array([3., 3., 3., ..., 2., 7., 2.])
# Coordinates:
#   * time     (time) int64 0 1 2 3 4 5 6 7 ... 7283 7284 7285 7286 7287 7288 7289

# %%
bmu.to_netcdf(bmu_filename)

# %%
data
# Out:
# <xarray.DataArray 'preSOM' (time: 7290, z: 11651)>
# array([[ 307.19569639,  430.7513085 ,  548.52521231, ...,   -3.33405712,
#          -11.32420314,  -18.08370517],
#        [ -16.50076608,   54.92982404,  142.58657422, ...,    2.32959031,
#           -5.90205393,  -10.93550531],
#        [ 176.45973612,  240.87277372,  285.4887377 , ...,  -32.81129443,
#          -44.14736339,  -52.68890047],
#        ...,
#        [-170.64117719,  -95.08775797,  -64.20567834, ...,   37.26571836,
#           30.8648394 ,   22.22764533],
#        [-271.98736096, -128.86410444,   15.60254168, ...,  125.90605032,
#          114.32568725,  110.08770486],
#        [-365.42012183, -290.67908799, -237.41636479, ...,  325.96106732,
#          304.92913245,  284.37740867]])
# Coordinates:
#   * time       (time) datetime64[ns] 1981-01-01 1981-01-02 ... 2020-12-31
#     dayofyear  (time) int64 ...
#     longitude  (z) float64 150.0 150.0 150.0 150.0 ... 340.0 340.0 340.0 340.0
#     latitude   (z) float64 70.0 69.0 68.0 67.0 66.0 ... 14.0 13.0 12.0 11.0 10.0
#   * z          (z) int64 0 1 2 3 4 5 6 ... 11645 11646 11647 11648 11649 11650
